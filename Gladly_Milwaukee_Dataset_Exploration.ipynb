# %% [markdown]
# # Problem Statement
# Imagine you've been hired as a senior data scientist by the City of Milwaukee. Your task is to analyze data from their call center operations. The city has carefully collected this data — now it's your mission to explore it, uncover insights, and provide recommendations. We're most interested in how you think, so be sure to walk us through your reasoning and the approaches you choose. Use your analytical skills and creativity to tell a compelling story, and support your insights with clear, effective visualizations.

# %% [markdown]
# # Load & Explore the Data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install wordcloud
from wordcloud import WordCloud
# !pip install pandas_profiling
# !pip install ydata_profiling

# %%
df_hist = pd.read_csv("/content/callcenterdatacurrent.csv")
df_curr = pd.read_csv("/content/callcenterdatahistorical.csv")

# %%
df_hist.head()
# Out:
#           CREATIONDATE                                      OBJECTDESC  \
# 0  2025-06-15 00:00:00                                  2634 N 59TH ST
# 1  2025-06-15 00:00:00  3720 W FAIRMOUNT AV, MILWAUKEE, WI, 53209-5348
# 2  2025-06-15 00:00:00      9719 W TOWER AV, MILWAUKEE, WI, 53224-2998
# 3  2025-06-15 00:00:00   1984 W CONGRESS ST, MILWAUKEE, WI, 53209-0000
# 4  2025-06-15 00:00:00     300 S BARCLAY ST, MILWAUKEE, WI, 53204-1623
#
#                                                TITLE       CLOSEDDATETIME  \
# 0            Illegal Auto Repair on Private Property  2025-06-16 00:00:00
# 1    Scattered Litter and Debris on Private Property                  NaN
# 2  Brush Pickup Request, Less than 2 Cubic Yards,...                  NaN
# 3                          Windows Broken or Missing                  NaN
# 4          Bulky Pickup & San Inspector Notification                  NaN
#
#                         CASECLOSUREREASONDESCRIPTION
# 0  Please keep my information confidential. Neigh...
# 1  According to the constituent, trash has been l...
# 2  Please pick up brush next to and west of the d...
# 3  Windows are busted out because they are contin...
# 4  POLICECALL P2506141211 // SOUTH OF LOCATION ON...

# %%
df_curr.head()
# Out:
#           CREATIONDATE                                         OBJECTDESC  \
# 0  2024-12-31 00:00:00  6000 W KINNICKINNIC RIVER PK, MILWAUKEE, WI, 5...
# 1  2024-12-31 00:00:00                            4701 W WASHINGTON BL, 1
# 2  2024-12-31 00:00:00          4719 W NASH ST, MILWAUKEE, WI, 53216-2918
# 3  2024-12-31 00:00:00        3141 S QUINCY AV, MILWAUKEE, WI, 53207-2717
# 4  2024-12-31 00:00:00          2800 N 72ND ST, MILWAUKEE, WI, 53210-1105
#
#                         TITLE       CLOSEDDATETIME  \
# 0                   Area Dark  2025-01-01 00:00:00
# 1                    Potholes                  NaN
# 2  Missed Collection: Garbage  2024-12-31 00:00:00
# 3  Missed Collection: Garbage                  NaN
# 4                   Area Dark  2025-01-01 00:00:00
#
#                         CASECLOSUREREASONDESCRIPTION
# 0  Lights along kk parkway between 60th and Cleve...
# 1  Potholes are bad to the east of N 47th St on W...
# 2  Checked  online and checked printed schedule g...
# 3  Our garbage and recycling bins haven’t been se...
# 4               Lights have been out since Christmas

# %%
df_curr.tail()
# Out:
#                CREATIONDATE                                       OBJECTDESC  \
# 165251  2020-04-27 00:00:00  3925 W FOREST HOME AV, MILWAUKEE, WI, 532153536
# 165252  2020-04-27 00:00:00         1628 N 36TH ST, MILWAUKEE, WI, 532082346
# 165253  2020-04-26 00:00:00   915 R E WISCONSIN AV, MILWAUKEE, WI, 532020000
# 165254  2020-04-25 00:00:00       3060 N GORDON CR, MILWAUKEE, WI, 532122224
# 165255  2020-03-21 00:00:00                             Santa Clara, CA, USA
#
#                                                     TITLE  \
# 165251  Drainage or Standing Water Not Related to a Cl...
# 165252                              Garbage Cart: No Cart
# 165253    Other Miscellaneous Electrical Services Request
# 165254                  Recycling Supervisor Notification
# 165255             Ask the City of Santa Clara a question
#
#              CLOSEDDATETIME                       CASECLOSUREREASONDESCRIPTION
# 165251                  NaN  Alley has sunken allowing it to collect and ho...
# 165252                  NaN  Address has no garbage or recycling carts.  We...
# 165253  2020-04-27 00:00:00  The big clock on the Miller Brewing Pavilion h...
# 165254                  NaN                                 Missed collections
# 165255  2020-03-22 00:00:00  Is Santa Clara going to issue a moratorium on ...

# %%
df_hist.shape, df_curr.shape
# Out:
# ((4174, 5), (165256, 5))

# %% [markdown]
# **Insight:**.
# - Historical dataset has 4174 records while current dataset has 165256 records

# %%
# Check if historical datset is a subset of current dataset

df_hist_sorted = df_hist[sorted(df_hist.columns)]
df_curr_sorted = df_curr[sorted(df_curr.columns)]


records_df_hist = set(map(tuple, df_hist_sorted.to_numpy()))
records_df_curr = set(map(tuple, df_curr_sorted.to_numpy()))


all_included = records_df_hist.issubset(records_df_curr)
print("All records of df_hist are in df_curr:", all_included)
# Out:
# All records of df_hist are in df_curr: False

# %%
df_curr.duplicated().sum()
# Out:
# np.int64(36981)

# %% [markdown]
# **Insight:**.
#  - They are two different datasets

# %%
# convert CREATIONDATE and CLOSEDDATETIME columns to datetime format

df_hist['CREATIONDATE'] = pd.to_datetime(df_hist['CREATIONDATE'])
df_hist['CLOSEDDATETIME'] = pd.to_datetime(df_hist['CLOSEDDATETIME'])
df_curr['CREATIONDATE'] = pd.to_datetime(df_curr['CREATIONDATE'])
df_curr['CLOSEDDATETIME'] = pd.to_datetime(df_curr['CLOSEDDATETIME'])

# %%
df_hist.info(), df_curr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4174 entries, 0 to 4173
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   CREATIONDATE                  4174 non-null   datetime64[ns]
#  1   OBJECTDESC                    4174 non-null   object
#  2   TITLE                         4174 non-null   object
#  3   CLOSEDDATETIME                1714 non-null   datetime64[ns]
#  4   CASECLOSUREREASONDESCRIPTION  3476 non-null   object
# dtypes: datetime64[ns](2), object(3)
# memory usage: 163.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165256 entries, 0 to 165255
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   CREATIONDATE                  165256 non-null  datetime64[ns]
#  1   OBJECTDESC                    116100 non-null  object
#  2   TITLE                         165256 non-null  object
#  3   CLOSEDDATETIME                69920 non-null   datetime64[ns]
#  4   CASECLOSUREREASONDESCRIPTION  113868 non-null  object
# dtypes: datetime64[ns](2), object(3)
# memory usage: 6.3+ MB
# (None, None)

# %%
# check earliest date for each datset

print("Earliest date in df_hist:", df_hist['CREATIONDATE'].min())
print("Earliest date in df_curr:", df_curr['CREATIONDATE'].min())
# Out:
# Earliest date in df_hist: 2025-01-01 00:00:00
# Earliest date in df_curr: 2020-03-21 00:00:00

# %% [markdown]
# **Insight:**
# Historical data has newer records than current dataset

# %%
# Join the two datasets
df = pd.concat([df_hist, df_curr], ignore_index=True)
df.head()
# Out:
#   CREATIONDATE                                      OBJECTDESC  \
# 0   2025-06-15                                  2634 N 59TH ST
# 1   2025-06-15  3720 W FAIRMOUNT AV, MILWAUKEE, WI, 53209-5348
# 2   2025-06-15      9719 W TOWER AV, MILWAUKEE, WI, 53224-2998
# 3   2025-06-15   1984 W CONGRESS ST, MILWAUKEE, WI, 53209-0000
# 4   2025-06-15     300 S BARCLAY ST, MILWAUKEE, WI, 53204-1623
#
#                                                TITLE CLOSEDDATETIME  \
# 0            Illegal Auto Repair on Private Property     2025-06-16
# 1    Scattered Litter and Debris on Private Property            NaT
# 2  Brush Pickup Request, Less than 2 Cubic Yards,...            NaT
# 3                          Windows Broken or Missing            NaT
# 4          Bulky Pickup & San Inspector Notification            NaT
#
#                         CASECLOSUREREASONDESCRIPTION
# 0  Please keep my information confidential. Neigh...
# 1  According to the constituent, trash has been l...
# 2  Please pick up brush next to and west of the d...
# 3  Windows are busted out because they are contin...
# 4  POLICECALL P2506141211 // SOUTH OF LOCATION ON...

# %%
# check number of unique values

df.nunique()
# Out:
# CREATIONDATE                     1862
# OBJECTDESC                      73433
# TITLE                             375
# CLOSEDDATETIME                   1581
# CASECLOSUREREASONDESCRIPTION    93135
# dtype: int64

# %%
# Check for duplicate rows

print(f"Number of duplicate rows: {df.duplicated().sum()}")
# Out:
# Number of duplicate rows: 36985

# %% [markdown]
# **Insight:**.
# - About 36985 records are duplicated

# %%
# check missing values

df.isnull().sum()
# Out:
# CREATIONDATE                        0
# OBJECTDESC                      49156
# TITLE                               0
# CLOSEDDATETIME                  97796
# CASECLOSUREREASONDESCRIPTION    52086
# dtype: int64

# %%
# check ratio of missing values to total

print(f"{df.isnull().sum() / len(df) *100}")
# Out:
# CREATIONDATE                     0.000000
# OBJECTDESC                      29.012572
# TITLE                            0.000000
# CLOSEDDATETIME                  57.720593
# CASECLOSUREREASONDESCRIPTION    30.741899
# dtype: float64

# %%
#  ratio of missing data as percentage
missing_percentage = df.isna().mean() * 100
formatted = missing_percentage.round(1).astype(str) + '%'
print(formatted)
# Out:
# CREATIONDATE                     0.0%
# OBJECTDESC                      29.0%
# TITLE                            0.0%
# CLOSEDDATETIME                  57.7%
# CASECLOSUREREASONDESCRIPTION    30.7%
# dtype: object

# %% [markdown]
# **Insight :**
#
# A high proportion of data is missing. We need to check with the data injestion team what is happening.

# %%
df.shape
# Out:
# (169430, 5)

# %%
# Convert date fields to datetime

# %%
df.describe(include='all')
# Out:
#                          CREATIONDATE  \
# count                          169430
# unique                            NaN
# top                               NaN
# freq                              NaN
# mean    2021-03-11 09:16:13.867673856
# min               2020-03-21 00:00:00
# 25%               2020-07-20 00:00:00
# 50%               2020-09-25 00:00:00
# 75%               2020-11-18 00:00:00
# max               2025-06-15 00:00:00
#
#                                               OBJECTDESC  \
# count                                             120274
# unique                                             73433
# top     841 N BROADWAY, MILWAUKEE, WISCONSIN, 53202-3607
# freq                                                  79
# mean                                                 NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#                                                     TITLE  \
# count                                              169430
# unique                                                375
# top     Brush Pickup Request, Less than 2 Cubic Yards,...
# freq                                                11395
# mean                                                  NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                        CLOSEDDATETIME CASECLOSUREREASONDESCRIPTION
# count                           71634                       117344
# unique                            NaN                        93135
# top                               NaN   Is night parking enforced?
# freq                              NaN                         1044
# mean    2021-03-10 12:54:16.554150656                          NaN
# min               2020-03-22 00:00:00                          NaN
# 25%               2020-08-15 00:00:00                          NaN
# 50%               2020-10-08 00:00:00                          NaN
# 75%               2020-11-17 00:00:00                          NaN
# max               2025-06-16 00:00:00                          NaN

# %% [markdown]
# # EDA

# %%
# create a profile report for the data
from ydata_profiling import ProfileReport
profile = ProfileReport(df)
profile.to_file(output_file='Gladly_Case_Profile_report.html')
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#  20%|██        | 1/5 [00:00<00:00,  9.41it/s]
#  40%|████      | 2/5 [00:05<00:10,  3.43s/it]
# 100%|██████████| 5/5 [00:08<00:00,  1.66s/it]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # WordCloud for each column

# %%
# check which columns of df contain text

for col in df.columns:
    if df[col].dtype == 'object':
        print(f"Column '{col}'")
# Out:
# Column 'OBJECTDESC'
# Column 'TITLE'
# Column 'CASECLOSUREREASONDESCRIPTION'

# %%
df.columns
# Out:
# Index(['CREATIONDATE', 'OBJECTDESC', 'TITLE', 'CLOSEDDATETIME',
#        'CASECLOSUREREASONDESCRIPTION'],
#       dtype='object')

# %%
# Function to generate Wordcloud

def Column_WordCloud(df, text_columns):
  for col in text_columns:
    if not df[col].isnull().all() and df[col].dtype == 'object':
      text = " ".join(str(item) for item in df[col].dropna().unique())
      if text:
          wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

          plt.figure(figsize=(10, 5))
          plt.imshow(wordcloud, interpolation='bilinear')
          plt.axis("off")
          plt.title(f'Word Cloud for {col}')
          plt.show()

# %%
# Wordcloud
Column_WordCloud(df, ["OBJECTDESC"])

# %% [markdown]
# **Insights:**.
# - "Milwaukee" and "Wisconsin" occur frequently in the OBJECTDESC column

# %%
Column_WordCloud(df, ["TITLE"])

# %% [markdown]
# **Insights:**.
# - Words such as "Information", "Info" and "Internal Transfer" occur frequently in the TITLE column

# %%
Column_WordCloud(df, ["CASECLOSUREREASONDESCRIPTION"])

# %% [markdown]
# **Insights:**.
# - Phrase such as "Caller state", "front" and "Street" occur frequently in the CASECLOSUREREASONDESCRIPTION column

# %% [markdown]
# # Recommendations:

# %% [markdown]
#  - A high proportion of data is missing. We need to check with the data injestion team what is happening.
#  - Historical dataset is newer than current dataset. Check with data injestion if this was an error.
#  - About 40000 data records are duplicated. Check the data injestion algorithms for errors.
